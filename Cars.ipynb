# %%
import pandas as pd

# %%
car=pd.read_csv(r"C:\Users\mansisrivastava\Desktop\PythpnDataScienceProject\cars2015.csv")

# %%
car.head()
# Out:
#          Make       Model       Type  LowPrice  HighPrice Drive  CityMPG  \
# 0   Chevrolet       Spark  Hatchback    12.270     25.560   FWD       30
# 1     Hyundai      Accent  Hatchback    14.745     17.495   FWD       28
# 2         Kia         Rio      Sedan    13.990     18.290   FWD       28
# 3  Mitsubishi      Mirage  Hatchback    12.995     15.395   FWD       37
# 4      Nissan  Versa Note  Hatchback    14.180     17.960   FWD       31
#
#    HwyMPG  FuelCap  Length  Width  Wheelbase  Height  UTurn  Weight  Acc030  \
# 0      39      9.0     145     63         94      61     34    2345     4.4
# 1      37     11.4     172     67        101      57     37    2550     3.7
# 2      36     11.3     172     68        101      57     37    2575     3.5
# 3      44      9.2     149     66         97      59     32    2085     4.4
# 4      40     10.9     164     67        102      61     37    2470     4.0
#
#    Acc060  QtrMile  PageNum   Size
# ...

# %%
car.shape     # find rows and columns of dataset
# Out:
# (110, 20)

# %%
car.isnull().sum() #  data cleaning (find if any null values in dataset, if any fill with the mean of dataset)
# Out:
# Make         0
# Model        0
# Type         0
# LowPrice     0
# HighPrice    0
# Drive        0
# CityMPG      0
# HwyMPG       0
# FuelCap      0
# Length       0
# Width        0
# Wheelbase    0
# Height       0
# UTurn        0
# Weight       0
# Acc030       0
# Acc060       0
# QtrMile      0
# PageNum      0
# Size         0
# dtype: int64

# %%
#check different types of make in dataset and occurance(count) of each make in dataset

# %%
car.head(2)
# Out:
#         Make   Model       Type  LowPrice  HighPrice Drive  CityMPG  HwyMPG  \
# 0  Chevrolet   Spark  Hatchback    12.270     25.560   FWD       30      39
# 1    Hyundai  Accent  Hatchback    14.745     17.495   FWD       28      37
#
#    FuelCap  Length  Width  Wheelbase  Height  UTurn  Weight  Acc030  Acc060  \
# 0      9.0     145     63         94      61     34    2345     4.4    12.8
# 1     11.4     172     67        101      57     37    2550     3.7    10.3
#
#    QtrMile  PageNum   Size
# 0     19.4      123  Small
# 1     17.8      148  Small

# %%
car['Make'].value_counts()
# Out:
# Chevrolet     8
# Toyoto        7
# Hyundai       7
# Ford          7
# Nissan        6
# Audi          6
# Kia           5
# BMW           5
# Cadillac      4
# Honda         4
# Mazda         3
# Subaru        3
# Volkswagon    3
# Dodge         3
# Chrysler      3
# Buick         3
# Lincoln       2
# Jeep          2
# Porche        2
# Acura         2
# Lexus         2
# Jaguar        2
# Volvo         2
# Mercedes      2
# Infiniti      2
# Dodge         2
# Scion         2
# GMC           2
# Mitsubishi    1
# Maserati      1
# Subaru        1
# Chevrolet     1
# Mazda         1
# Buick         1
# Fiat          1
# Land Rover    1
# Ford          1
# Name: Make, dtype: int64

# %%
# filtering (to show dataset where Model is Accent or Spark  )

# %%
car[car['Model'].isin(['Accent','Spark'])]
# Out:
#         Make   Model       Type  LowPrice  HighPrice Drive  CityMPG  HwyMPG  \
# 0  Chevrolet   Spark  Hatchback    12.270     25.560   FWD       30      39
# 1    Hyundai  Accent  Hatchback    14.745     17.495   FWD       28      37
#
#    FuelCap  Length  Width  Wheelbase  Height  UTurn  Weight  Acc030  Acc060  \
# 0      9.0     145     63         94      61     34    2345     4.4    12.8
# 1     11.4     172     67        101      57     37    2550     3.7    10.3
#
#    QtrMile  PageNum   Size
# 0     19.4      123  Small
# 1     17.8      148  Small

# %%
#Removing unwanted records (to remove dataset where weight is above 4000)

# %%
car[~(car['Weight']>4000)]
# Out:
#           Make         Model       Type  LowPrice  HighPrice Drive  CityMPG  \
# 0    Chevrolet         Spark  Hatchback    12.270     25.560   FWD       30
# 1      Hyundai        Accent  Hatchback    14.745     17.495   FWD       28
# 2          Kia           Rio      Sedan    13.990     18.290   FWD       28
# 3   Mitsubishi        Mirage  Hatchback    12.995     15.395   FWD       37
# 4       Nissan    Versa Note  Hatchback    14.180     17.960   FWD       31
# ..         ...           ...        ...       ...        ...   ...      ...
# 79         BMW            X1        SUV    31.200     39.100   RWD       22
# 80        Jeep       Compass        SUV    18.995     28.795   FWD       21
# 81  Land Rover  Range Evoque        SUV    41.100     60.000   AWD       18
# 83      Nissan         Rogue        SUV    22.790     29.630   FWD       25
# 84      Subaru      Forester        SUV    22.195     33.095   AWD       24
#
# ...

# %%
#Apply function on a column(Increase values of length column by 3)

# %%
#car['Length']=car['Length']+3
car['Length']=car['Length'].apply(lambda x:x+3)

# %%
car
# Out:
#            Make       Model       Type  LowPrice  HighPrice Drive  CityMPG  \
# 0     Chevrolet       Spark  Hatchback    12.270     25.560   FWD       30
# 1       Hyundai      Accent  Hatchback    14.745     17.495   FWD       28
# 2           Kia         Rio      Sedan    13.990     18.290   FWD       28
# 3    Mitsubishi      Mirage  Hatchback    12.995     15.395   FWD       37
# 4        Nissan  Versa Note  Hatchback    14.180     17.960   FWD       31
# ..          ...         ...        ...       ...        ...   ...      ...
# 105      Toyoto     Sequioa      7Pass    44.395     64.320   RWD       12
# 106      Nissan  Pathfinder      7Pass    29.510     43.100   FWD       19
# 107       Acura         MDX      7Pass    42.865     57.080   FWD       18
# 108     Hyundai    Santa Fe      7Pass    30.150     36.000   FWD       18
# 109        GMC        Yukon      7Pass    47.740     67.520   RWD       16
#
# ...
